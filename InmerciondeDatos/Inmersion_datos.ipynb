# %% [markdown]
# <a href="https://colab.research.google.com/github/juanmachanes/Portafolio/blob/main/InmerciondeDatos/Inmersion_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Montamos mi drive en colab

# %% [markdown]
# # Extraccion de Datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Le asignamos a la variable inmuebles el *csv*
#
# Traemos los primeros datos para comprobar que se cargo

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %% [markdown]
#  ## Vemos las caracteristicas de lo que se extrajo
#  Indica la cantidad de elementos y columnas

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# Renombramos las columnas ya que los caracteres especiales nos pueden dar problemas
# - tomamos una muestra de 10 datos

# %%
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 6613         Casa      Casa en venta en Zona Noroccidental             3
# 1503  Apartamento         Apartamento en venta en Cedritos             3
# 7830         Casa           Casa en venta en Puente Aranda             8
# 9062  Apartamento             Apartamento en venta en Suba             3
# 5134  Apartamento  Apartamento en venta en Chico Reservado             2
# 603   Apartamento          Apartamento en venta en Usaquén             3
# 1709  Apartamento        Apartamento en venta en Chapinero             3
# 2230  Apartamento          Apartamento en venta en Usaquén             3
# 7194         Casa                 Casa en venta en Tintala             3
# 7118  Apartamento    Apartamento en venta en Santa Barbara             1
#
#       Banos  Area              Barrio  \
# 6613      4   295  Zona Noroccidental
# 1503      3    99            Cedritos
# 7830      6   360       Puente Aranda
# ...

# %% [markdown]
# Con "Info" vemos la informacion que hay en el csv,
# - Tenemos un rango de 0 al 9519 filas (Total de 9520)
# - Los nombres y el orden de las columnas
# - Podemos ver que upz tiene algunos valores nulos ya que 9478 son no null y el total es de 9520

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %% [markdown]
# ## Formas de visualizar una fila determinada

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %% [markdown]
# ## Funciones aritmeticas
# - mean() calcula promedio
# - sum() suma
# - count() calcula el conteo
# - min() calcula el valor minimo
# - max() calcula el valor max

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %% [markdown]
# # Primeros Graficos

# %% [markdown]
# ## Grafica de cantidad de inmuebles en venta por barrios

# %%
inmuebles_barrio=inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ## Grafica de cantidad de inmuebles en venta por barrio (top 10 barrios de mayor cantidad de inmuebles en venta)
# Como en el grafico anterior es muy dificil visualizarlo, decidi ver solo los barrios con mayor disponibilidad

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# # Promedio de area de todos los barrios y estudio con grafico de los barrios con mas disponibilidad

# %%
barrio_area=inmuebles.groupby('Barrio')['Area'].mean()

# %%
barrio_area
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %%
top10=barrio_area.sort_values(ascending=False).head(10)
top10
# Out:
# Barrio
# Modelia                  4316.750000
# Libertador                642.000000
# Bosa Piamonte             400.000000
# La Soledad                378.625000
# Restrepo                  336.500000
# Santa Librada             328.000000
# Las Ferias                320.000000
# Santa Ana                 309.375000
# Veraguas                  302.666667
# Bellavista Occidental     286.200000
# Name: Area, dtype: float64

# %%
top10.plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %% [markdown]
# # Calculos estadisticos

# %% [markdown]
# Cantidad de M2 de Area por barrio

# %%
inmuebles.groupby('Barrio')['Area'].sum()
# Out:
# Barrio
# Alameda                   97
# Alhambra                3237
# Andes Norte              874
# Antonio Nariño          7827
# Barrancas               1053
#                        ...
# Villa Maria             2693
# Villas De Granada       1905
# Villemar                1384
# Zona Franca               54
# Zona Noroccidental    119084
# Name: Area, Length: 149, dtype: int64

# %% [markdown]
# Cantidad de inmuebles a la venta en el barrio 'Chico Reservado'

# %%
sum(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 225

# %% [markdown]
# Calculo de:
# - Cantidad de inmuebles en el barrio "Chico Reservado"
# - Area promedio de la venta en el barrio "Chico reservado"

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %% [markdown]
# Cantidad de barrios

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %% [markdown]
# Cantidad de inmuebles en venta por barrio

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %% [markdown]
# # Tratado de Variables

# %% [markdown]
# Podemos ver que la variable Valor es un Object(String) por lo que debemos tratarla para luego hacer calculos con 'Valor'

# %%
inmuebles.sample(5)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8834  Apartamento       Apartamento en venta en Engativa             3      3
# 4277         Casa               Casa en venta en Usaquén             3      5
# 472   Apartamento       Apartamento en venta en Cedritos             2      2
# 8336  Apartamento  Apartamento en venta en Puente Aranda             3      2
# 5710  Apartamento    Apartamento en venta en Teusaquillo             3      2
#
#       Area         Barrio                                             UPZ  \
# 8834   111       Engativa                                        Engativá
# 4277   231        Usaquén                                         Usaquén
# 472     64       Cedritos                                         Usaquén
# 8336    67  Puente Aranda  PUENTE ARANDA: Zona Industrial + Puente Aranda
# 5710    58    Teusaquillo                                     Teusaquillo
#
#                 Valor
# 8834    $ 370.000.000
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %%
inmuebles.Valor
# Out:
# 0         $ 360.000.000
# 1         $ 670.000.000
# 2       $ 1.120.000.000
# 3         $ 890.000.000
# 4         $ 970.000.000
#              ...
# 9515      $ 290.000.000
# 9516      $ 670.000.000
# 9517      $ 900.000.000
# 9518      $ 335.000.000
# 9519      $ 144.990.000
# Name: Valor, Length: 9520, dtype: object

# %% [markdown]
# Usamos split para poder separa el signo '$' con el valor

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
inmuebles.Valor[0].split()[1]
# Out:
# '360.000.000'

# %%
type(inmuebles.Valor)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Como la columna Valor es un pandas series, para usar el split debemos pasarlo a str
# - En realidad sigue siento un pandas series pero lo devuelve como un elemento de lista de str

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %% [markdown]
# Al poner expand=true en vez de devolverme un pandas Series me devuelve un dataframe de un formato de dos columnas

# %%
inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %% [markdown]
# Agregamos dos columnas mas con el precio y la moneda

# %%
valor= inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = valor[0]
inmuebles ['Precio'] = valor[1]

# %%
inmuebles.sample(10)
# Out:
#                      Tipo                                    Descripcion  \
# 7978          Apartamento              Apartamento en venta en Chapinero
# 7854          Apartamento              Apartamento en venta en Chapinero
# 8944          Apartamento                Apartamento en venta en Usaquén
# 4802                 Casa                     Casa en venta en Chapinero
# 5914          Apartamento               Apartamento en venta en Cedritos
# 3904          Apartamento          Apartamento en venta en Santa Barbara
# 5079          Apartamento              Apartamento en venta en El Virrey
# 6250                 Casa                      Casa en venta en Ricaurte
# 8874          Apartamento                Apartamento en venta en Kennedy
# 8762  Oficina/Consultorio  Oficina/Consultorio en venta en Santa Barbara
#
#       Habitaciones  Banos  Area         Barrio  \
# 7978             3      2    79      Chapinero
# 7854             3      3   202      Chapinero
# ...

# %% [markdown]
# Vemos que sigue siendo objeto el Precio

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# Podemos ver que el punto nos hace que siga siendo String, por lo tanto hay q sacar el punto.
# La que hacemos es reemplazar el punto por un string vacio

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex = True)

# %%
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# Sigue siendo String por lo que hay que transformarlo y dividimos por 1 millon para que sean numeros mas comodos

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %% [markdown]
# *YA ESTA CONVERTIDO A FLOAT!*

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format',lambda x: '%.2f' % x)

# %% [markdown]
# # Valores erroneos del Datagrama

# %% [markdown]
# Podemos que no tiene logica algunas cosas erroneas, es muy raro que un inmueble tenga 110 habitaciones

# %%
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# Confirmamos que es imposible que haya tantas habitaciones en un area tan chica

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %% [markdown]
# Tambien vemos que es poco probable que haya un inmueble con Area=2

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %% [markdown]
# Como analista de datos debemos darnos cuentas de estas cosas y tomar una desicion al respecto (borrar dato o averiguar el error y corregirlo)

# %% [markdown]
# # Grafico de cantidad de inmuebles por precio por millon

# %%
inmuebles['Precio_Millon'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Vemos que la gran cantidad de inmuebles anda desde los 0 a 1000 millones

# %% [markdown]
# ## Ahora con otras librerias vamos a mostrar graficos de mejor forma

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
grafica=sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribucion de valores de los inmuebles en bogota')
plt.xlim((50,1000))

plt.savefig('/content/drive/MyDrive/Inmersion_Datos/Distribucion.png',format='png')
plt.show()

# %% [markdown]
# Podemos ver en el grafico de arriba que los apartamentos son los inmuebles que mas variedad de precios hay, siguido de Casas

# %% [markdown]
# # Estudio con histograma la variacion de precios de imnuebles de tipo local,bodega y Edificio
# - Con el histograma podemos ver que hay una gran diversidad de precio para los locales, ya que hay opciones para cualquier precio
# - Por lo contrario las bodegas se centran con un precio menor a los 1000 millones
# - Los Edificion rondan entre 1000 y 2000 millones

# %%
inmuebles_tipos= inmuebles.loc[(inmuebles.Tipo == "Edificio") | (inmuebles.Tipo == "Local") | (inmuebles.Tipo == "Bodega")]
grafica = sns.histplot(data=inmuebles_tipos, x='Precio_Millon', hue='Tipo', multiple='stack')
plt.xlim((50,4000))
# Out:
# (50.0, 4000.0)

# %% [markdown]
# # Calculo y estudio del precio del M2
# Para calcular el precio de M2 por barrio podemos:
# - Calcular el M2 con la media y area general (valor_m2_millon)
# - Calcular el M2 por barrio con la media y (valor_m2_millon_barrio)

# %%
inmuebles['Valor_m2_Millon'] = inmuebles['Precio_Millon']/inmuebles['Area']

inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
# <ipython-input-52-45bba8259daf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datos_barrio = inmuebles.groupby('Barrio').sum()
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# ...

# %%
datos_barrio['Valor_del_M2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon  Valor_del_M2_Barrio
# Barrio
# Alameda                        5.98                 5.98
# Alhambra                      73.56                 3.95
# ...

# %%
m2_barrio = dict(datos_barrio['Valor_del_M2_Barrio'])
inmuebles['Valor_del_M2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_del_M2_Barrio'] = inmuebles['Valor_del_M2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon  \
# ...

# %%
inmuebles.head(10)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
# 5  Apartamento         Apartamento en venta en Bella Suiza             1
# 6  Apartamento         Apartamento en venta en Bella Suiza             1
# 7  Apartamento         Apartamento en venta en Bella Suiza             3
# 8  Apartamento            Apartamento en venta en El Chicó             3
# 9  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# ...

# %% [markdown]
# Barrios que tienen mas imuebles a la venta

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index
top_barrios
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_del_M2_Barrio
# 0               5.98                 5.98
# 1              73.56                 3.95
# ...

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_del_M2_Barrio
# 5            2070.61                 2.96
# 10           1654.36                 2.68
# 22           2853.23                 5.03
# 24           2466.03                 4.58
# ...

# %% [markdown]
# ## Graficamos

# %% [markdown]
# Se hizo un grafico de barra del Valor del M2 por barrio para cada uno de los barrios con mas disponibilidad de inmuebles
# - Como conclusion podemos decir que de los 10 barrios con mas inmuebles disponibles, "Santa barbara","Usaquen" y "Cedritos" son los barrios que se venden mas caro el m2

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x='Barrio',y='Valor_del_M2_Barrio', data = datos_barrio.query('Barrio in @top_barrios') )
ax.tick_params(axis='x', rotation=45)

# %% [markdown]
# Ahora hicimos un grafico boxplot con los mismo datos para poder ver con mas detalles

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Valor_m2_Millon', data = inmuebles.query('Barrio in @top_barrios') )
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Filtramos que el valor del m2 tiene que ser menor a 15 millones
# - podemos concluir que el Valor media del m2 es aproximadamente en 5 millones

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Area", data = inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Precio_Millon", data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# # Agregando Variables

# %% [markdown]
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# Encuesta Multiproposito de Bogotá para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %% [markdown]
# ## Vamos uniendo los csv en una misma tabla

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/archivos-dane/archivos-dane/Identificación (Capítulo A).csv',sep=';',encoding='latin-1')

# %%
datos_raw
# Out:
#         DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0       3004346.00    11  11001      1           3.00         Santa Fe
# 1       3004347.00    11  11001      1          14.00     Los Mártires
# 2       3004348.00    11  11001      1           3.00         Santa Fe
# 3       3004349.00    11  11001      1           1.00          Usaquén
# 4       3004350.00    11  11001      1           1.00          Usaquén
# ...            ...   ...    ...    ...            ...              ...
# 106462  3004341.00    11  11001      1           3.00         Santa Fe
# 106463  3004342.00    11  11001      1           3.00         Santa Fe
# 106464  3004343.00    11  11001      1          14.00     Los Mártires
# 106465  3004344.00    11  11001      1           3.00         Santa Fe
# 106466  3004345.00    11  11001      1           3.00         Santa Fe
#
#         COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# ...

# %% [markdown]
# Solo necesitamos los datos del municipio de bogota (11001)

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/archivos-dane/archivos-dane/Datos de la vivenda y su entorno (Capítulo B).csv',sep=';',encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/archivos-dane/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/archivos-dane/archivos-dane/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/archivos-dane/archivos-dane/Educación (Capítulo H).csv',sep=';',encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/archivos-dane/archivos-dane/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv',sep=';',encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/archivos-dane/archivos-dane/Fuerza de trabajo (Capítulo K).csv',sep=';',encoding='latin-1')
# Out:
# <ipython-input-67-59f282db64e1>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/archivos-dane/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
# <ipython-input-67-59f282db64e1>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/archivos-dane/archivos-dane/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
# <ipython-input-67-59f282db64e1>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/archivos-dane/archivos-dane/Educación (Capítulo H).csv',sep=';',encoding='latin-1')
# ...

# %%
datos_dane = pd.merge(datos_raw,datos_b,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-70-a8281422ec17>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# ## Usamos una csv con los datos mas limpios

# %%
datos_dane = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/datos_dane.csv')
datos_dane.head()
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0  3004368.00          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1  3004369.00          Usaquén                                        Usaquén
# 2  3004375.00        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3  3004380.00          Usaquén                                     Los Cedros
# 4  3004383.00         Fontibón                      Ciudad Salitre Occidental
#
#    NVCBP4  NVCBP14A  NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  \
# 0       1         2         2         2         2         2         2  ...
# 1       1         2         2         2         2         2         2  ...
# 2       2         2         2         2         2         2         1  ...
# 3       1         2         2         2         2         2         2  ...
# 4       1         2         2         2         2         1         2  ...
#
# ...

# %%
datos_dane.shape
# Out:
# (9857, 55)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %% [markdown]
# Renombaramos las columnas --> Buscamos en la documentacion que significaba cada codigo y le puse nombrs mas correctos

# %%
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO',
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES',
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES',
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA',
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19',
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA',
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO',
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA',
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO',
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO',
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns=dic_dane)
datos_dane.columns
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
# ...

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DIRECTORIO                 9857 non-null   float64
#  1   NOMBRE_LOCALIDAD           9857 non-null   object
#  2   NOMBRE_ESTRATO             9857 non-null   object
#  3   CONJUNTO_CERRADO           9857 non-null   int64
#  4   FABRICAS_CERCA             9857 non-null   int64
#  5   TERMINALES_BUS             9857 non-null   int64
#  6   BARES_DISCO                9857 non-null   int64
#  7   OSCURO_PELIGROSO           9857 non-null   int64
#  8   RUIDO                      9857 non-null   int64
#  9   INSEGURIDAD                9857 non-null   int64
#  10  BASURA_INADECUADA          9857 non-null   int64
#  11  INVASION                   9857 non-null   int64
#  12  MOV_ADULTOS_MAYORES        9857 non-null   int64
# ...

# %% [markdown]
# ## Agrupamos por UPZ y tomamos algunas para calcular el promedio de cada columna

# %%
datos_dane.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head()
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.89
# Américas                                                      1.38
# Apogeo                                                        1.65
# Arborizadora                                                  1.43
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.37
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.19            1.85
# Américas                                                 1.25            1.98
# Apogeo                                                   1.30            1.75
# Arborizadora                                             1.30            1.95
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.33            1.99
#
# ...

# %%
datos = datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)
datos
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %%
datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %% [markdown]
# ## Unimos la tabla de los inmuebles con los datos Dane

# %%
pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
datos_ml = pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Banos                     9520 non-null   int64
#  4   Area                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Moneda                    9520 non-null   object
#  9   Precio                    9520 non-null   object
#  10  Precio_Millon             9520 non-null   float64
#  11  Valor_m2_Millon           9520 non-null   float64
#  12  Valor_del_M2_Barrio       9520 non-null   float64
# ...

# %% [markdown]
# ## Como UPZ es un string hacemos un marge con la tabla de cod_upz para obtener el codigo de cada uno

# %%
upz = pd.read_csv('/content/drive/MyDrive/Inmersion_Datos/archivos-dane/archivos-dane/cod_upz.csv')
datos_ml = pd.merge(datos_ml,upz,left_on='UPZ',right_on='NOMBRE_ESTRATO', how='inner')
datos_ml.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                      Casa en venta en Marly             3
# 2         Casa         Casa en venta en Zona Noroccidental             3
# 3  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4         Casa         Casa en venta en Zona Noroccidental             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2      4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3      1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4      6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor Moneda      Precio  ...  BARES_DISCO  RUIDO  \
# ...

# %%
datos_ml.shape
# Out:
# (9318, 26)

# %%
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9318 entries, 0 to 9317
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9318 non-null   object
#  1   Descripcion               9318 non-null   object
#  2   Habitaciones              9318 non-null   int64
#  3   Banos                     9318 non-null   int64
#  4   Area                      9318 non-null   int64
#  5   Barrio                    9318 non-null   object
#  6   UPZ                       9318 non-null   object
#  7   Valor                     9318 non-null   object
#  8   Moneda                    9318 non-null   object
#  9   Precio                    9318 non-null   object
#  10  Precio_Millon             9318 non-null   float64
#  11  Valor_m2_Millon           9318 non-null   float64
#  12  Valor_del_M2_Barrio       9318 non-null   float64
# ...

# %% [markdown]
# ## Analizamos los graficos
# - Vemos en el boxplot que hay varios valores atipicos, por lo que lo sacamos de los datos
# - Estos valores atipicos nos pueden aumentar el error de prediccion en nuestro modelo de machine learning

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, y = 'Precio_Millon')
plt.show()

# %%
datos_ml.query('Precio_Millon > 1200 | Precio_Millon < 60')
# Out:
#              Tipo                          Descripcion  Habitaciones  Banos  \
# 2            Casa  Casa en venta en Zona Noroccidental             3      4
# 4            Casa  Casa en venta en Zona Noroccidental             3      6
# 5            Casa  Casa en venta en Zona Noroccidental             3      5
# 6            Casa  Casa en venta en Zona Noroccidental             5      5
# 7            Casa  Casa en venta en Zona Noroccidental             4      5
# ...           ...                                  ...           ...    ...
# 9275  Apartamento    Apartamento en venta en El Virrey             3      3
# 9289        Local         Local en venta en Libertador             5      6
# 9290        Local         Local en venta en Libertador             5      6
# 9308  Apartamento  Apartamento en venta en El Castillo             3      5
# 9309  Apartamento  Apartamento en venta en El Castillo             3      5
#
# ...

# %%
datos_ml = datos_ml.query('Precio_Millon < 1200 & Precio_Millon > 60')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9            Casa         Casa en venta en Zona Noroccidental             5
# 10    Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, y = 'Precio_Millon')
plt.show()

# %% [markdown]
# ## Agregamos una columna con salario anual por millon para que sea mas facil el tratado de la variable

# %%
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_MI']
# Out:
# 0      48.42
# 1      48.42
# 3      48.42
# 9      48.42
# 10     48.42
#         ...
# 9313   29.34
# 9314   29.34
# 9315   29.34
# 9316   29.34
# 9317   29.34
# Name: SALARIO_ANUAL_MI, Length: 8313, dtype: float64

# %% [markdown]
# ## Grafico Scatter
# - Podemos ver que el salario anual y el valor del m2 no depende mucho, ya que para cada Salario anual vemos distintos valores de m2

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=datos_ml, x='SALARIO_ANUAL_MI',y ='Valor_m2_Millon')
plt.ylim((0,15))
plt.show()

# %% [markdown]
# ## Hacemos un cuadro de correlacion para ver las dependencias de la variables
# - -1 = Inversa
# - 0 = Sin correlacion
# - 1 = Directa

# %%
datos_ml.corr()
# Out:
# <ipython-input-91-06e284398928>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datos_ml.corr()
#                           Habitaciones  Banos  Area  Precio_Millon  \
# Habitaciones                      1.00   0.44  0.03           0.18
# Banos                             0.44   1.00  0.04           0.66
# Area                              0.03   0.04  1.00           0.04
# Precio_Millon                     0.18   0.66  0.04           1.00
# Valor_m2_Millon                  -0.31  -0.03 -0.04           0.36
# Valor_del_M2_Barrio              -0.21   0.13 -0.04           0.40
# CONJUNTO_CERRADO                 -0.12   0.16 -0.01           0.32
# INSEGURIDAD                       0.13  -0.19 -0.00          -0.37
# TERMINALES_BUS                    0.08  -0.17 -0.01          -0.28
# ...

# %%
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);
# Out:
# <ipython-input-92-eafa0665ea9a>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')

# %% [markdown]
# # Modelo Machine Learning

# %% [markdown]
# Hacemos un Split de los datos
# - test_size nos dice que el 25% de los datos se van a usar para testear, el otro 75% para entrenar
# - Random_state lo usamos para que tome los datos pseudoaleatoriamente, para garantizar la reproductivilidad

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = datos_ml[['COD_UPZ_GRUPO']]
y = datos_ml['Precio_Millon']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=99)

# %% [markdown]
# Instanciamos el Modelo

# %%
modelo = LinearRegression()

# %% [markdown]
# Entrenamos el modelo con los datos de entrenamiento

# %%
modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict_test = modelo.predict(X_test)

# %% [markdown]
# Ahora podemos ver la precision comparando los resultados en y_predict_test con Y_test
# - Vemos que tiene un error de 187 millones
# - y una presicion de 0.03

# %%
from sklearn.metrics import mean_absolute_error, r2_score

baseline_mae = mean_absolute_error(y_test, y_predict_test)
baseline_r2 = r2_score(y_test, y_predict_test)
print(baseline_mae,baseline_r2)
# Out:
# 187.323609443345 0.031111799984413713

# %% [markdown]
# Como nos dieron valores muy bajos, vamos agregar variables al modelo
# - Aumento la presicion y bajo el error
# - Los primeros dos valores comparamos con los valores del test
# - Los ultimos dos valores comparamos con los datos de entrenamiento (Datos que el modelo conoce)

# %%
modelo_1.predict([[816,3,2,1,50,1]])

X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']]

y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 118.25967274431333 0.5404735562069192
# 123.22271988681676 0.5269614226488988
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Al modelo le paso valores reales para que el modelo nos estime un precio**
# - Cod_UPZ=816
# - 3 Habitaciones
# - 2 baños
# - Esta en un conjunto cerrado
# - Las personas promedio ganan 50 millones de pesos al año
# - Tiene escritura

# %%
modelo_1.predict([[816,3,2,1,50,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([434.21129691])

# %% [markdown]
# Valdria 434 millones de pesos

# %% [markdown]
# ## Analisis Variable Seguridad (Modelo 2)

# %% [markdown]
# Analizamos la cantidad de salario anual de la persona por millon con las variables:
# - Conjunto Cerrado
# - Terminales Bus
# - Bares y Discos
# - Ruido
# - Oscuro Peligroso
# - Salario anual por millon

# %%
X = datos_ml[['CONJUNTO_CERRADO','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_ANUAL_MI']]
y = datos_ml['INSEGURIDAD']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=99)

# %% [markdown]
# Vemos que tiene una presicion de 85%

# %%
modelo_2 = LinearRegression()
modelo_2.fit(X_train, y_train)
y_predict_test = modelo_2.predict(X_test)
y_predict_train = modelo_2.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 0.06104159942259016 0.854517163768922
# 0.05971022581798594 0.864579321311996

# %% [markdown]
# Predecimos con el modelo un ejemplo con:
# - Conjunto Cerrado = NO
# - Terminales Bus = SI
# - Bares y Discos = SI
# - Ruido = SI
# - Oscuro Peligroso = SI
# - Salario anual por millon = 50 millones

# %%
modelo_2.predict([[0,1,1,1,1,50]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.55570215])

# %% [markdown]
# Predecimos con el modelo un ejemplo con:
# - Conjunto Cerrado = SI
# - Terminales Bus = SI
# - Bares y Discos = NO
# - Ruido = NO
# - Oscuro Peligroso = SI
# - Salario anual por millon = 70 millones

# %%
modelo_2.predict([[1,1,0,0,1,70]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.39634047])

# %% [markdown]
# ### Conclusion:
# Podemos ver que el primero es mas inseguro que el segundo, esto es coherente ya que hay bares y discos, ruido y oscuridad, a diferencia del otro que hay menos seguridad que si es oscuro pero no es ruidoso, no hay bares ni discos
